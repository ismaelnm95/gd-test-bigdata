# %% [markdown]
# ## Inicializar Spark y probar conexión

# %%
from utils import get_spark_session
spark = get_spark_session()
print(spark)
# Out:
# 25/04/30 23:47:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/30 23:47:01 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/04/30 23:47:01 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# ...
